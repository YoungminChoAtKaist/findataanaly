# %%
import pandas as pd

# %%
df = pd.read_csv('init_data.csv')

# %%
df
# Out:
#          nts_code  biz_type  idscdid sido             conm_nm  life_days  \
# 0             101         1  56114.0   서울             김밥천국삼청점       4766
# 1             101         1  56122.0   서울               명송 하나       5791
# 2             101         1  47312.0   서울                가인전자       2586
# 3             101         1  20400.0   서울               켐스펙교역       2371
# 4             101         1  46596.0  서울                동광전업사       2477
# ...           ...       ...      ...  ...                 ...        ...
# 1643712       899        93  46312.0   부산                경북농산       2023
# 1643713       899        94  96921.0  NaN      더블유(W) 요양병원 예산       1579
# 1643714       899        96  90212.0   대구              글나루독서실        868
# 1643715       899        97  96921.0   전북                  길묘        363
# 1643716       904        84  75999.0   서울  마쓰시마 메저 테크 서울연락사무소       4140
#
#           obzdate  clsbiz_date
# 0        19941001     20071019
# ...
